# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

from process import load_dataset, METRICS_CONFIGS
sns.set_theme()

# %%
metrics_config_index = 0

# %%
train_dataset, test_dataset = load_dataset(metrics_config_index, True), load_dataset(
    metrics_config_index, False
)

# %%
train_dataset
# Out:
#           TIMESTAMP      DURATION    PROBE      KIND  LAYER  CORE  PAIR_ON
# 0       47919123718  43932.961538  SENS_C1  INTERVAL  PROBE     1       63  \
# 1       47920723278  43995.615385  SENS_C1  INTERVAL  PROBE     1       63
# 2       47922323308  44108.807692  SENS_C1  INTERVAL  PROBE     1       63
# 3       47923923274  44220.653846  SENS_C1  INTERVAL  PROBE     1       63
# 4       47925523263  44466.115385  SENS_C1  INTERVAL  PROBE     1       63
# ...             ...           ...      ...       ...    ...   ...      ...
# 23335  751275762609  51888.423077  SENS_C1  INTERVAL  PROBE     1       63
# 23336  751277362626  51212.653846  SENS_C1  INTERVAL  PROBE     1       63
# 23337  751278962608  50579.538462  SENS_C1  INTERVAL  PROBE     1       63
# 23338  751280562646  50100.769231  SENS_C1  INTERVAL  PROBE     1       63
# 23339  751282162629  49166.038462  SENS_C1  INTERVAL  PROBE     1       63
#
# ...

# %%
test_dataset
# Out:
#            TIMESTAMP      DURATION    PROBE      KIND  LAYER  CORE  PAIR_ON
# 0          967064187  45235.884615  SENS_C1  INTERVAL  PROBE     1       63  \
# 1          968643281  45076.269231  SENS_C1  INTERVAL  PROBE     1       63
# 2          970243349  45211.192308  SENS_C1  INTERVAL  PROBE     1       63
# 3          971843321  45275.615385  SENS_C1  INTERVAL  PROBE     1       63
# 4          973443304  45447.153846  SENS_C1  INTERVAL  PROBE     1       63
# ...              ...           ...      ...       ...    ...   ...      ...
# 11665  1557902819032  51822.846154  SENS_C1  INTERVAL  PROBE     1       63
# 11666  1557904419029  51109.692308  SENS_C1  INTERVAL  PROBE     1       63
# 11667  1557906019013  50507.346154  SENS_C1  INTERVAL  PROBE     1       63
# 11668  1557907619023  49919.000000  SENS_C1  INTERVAL  PROBE     1       63
# 11669  1557909219013  49031.769231  SENS_C1  INTERVAL  PROBE     1       63
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

x_cols = ["DURATION"] + METRICS_CONFIGS[metrics_config_index]
train_X, train_Y = train_dataset[x_cols].to_numpy(), train_dataset["CLASS"].to_numpy()
test_X, test_Y = test_dataset[x_cols].to_numpy(), test_dataset["CLASS"].to_numpy()

# %%
scaler = StandardScaler()
scaler.fit(train_X)
train_X = scaler.transform(train_X)
test_X = scaler.transform(test_X)

# %%
# Train and test an SVM
from sklearn.svm import SVC

clf = SVC()
clf.fit(train_X, train_Y)
pred_Y = clf.predict(test_X)
accuracy_score(test_Y, pred_Y)
# Out:
# 0.9885175664095972
